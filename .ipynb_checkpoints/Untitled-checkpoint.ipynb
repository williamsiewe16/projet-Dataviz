# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import streamlit as st

# %%
df = pd.read_csv("https://drive.google.com/file/d/1MZ8k27u37fSK5Y88-OkL6RUtV4-2gzTv/view?usp=sharing", index_col=0)

# %%
df.shape
# Out:
# (172, 721)

# %%
df.head()
# Out:
#                                                     400  500  \
# <!DOCTYPE html><html><head><meta name="google" ...
# try{                                                NaN  NaN
# /*                                                  NaN  NaN
#  Copyright The Closure Library Authors.             NaN  NaN
#  SPDX-License-Identifier: Apache-2.0                NaN  NaN
# */                                                  NaN  NaN
#
#                                                    700" nonce="563L2P9B7pio1yMMSz7HVQ"><link rel="stylesheet" href="https://www.gstatic.com/_/apps-fileview/_/ss/k=apps-fileview.v.EYb5rFmw7Gw.L.X.O/am=DA/d=0/rs=AO0039vjImZ7r5zGcIeLXk48ZZYPgJ1WLg" nonce="563L2P9B7pio1yMMSz7HVQ"><script nonce="QQR415Cf1bmlR4StRYqpqQ">_docs_flag_initialData={"docs-ails":"docs_cold"  \
# <!DOCTYPE html><html><head><meta name="google" ...
# try{                                                                                              NaN
# ...
